# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df[df.duplicated()]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 164   38    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output
# 164    4      2       1

# %%
df.drop_duplicates(keep ='first', inplace=True)

# %% [markdown]
# ### Gender Categorization

# %%
x = (df.sex.value_counts())
print(f'Number of people having sex as 1 are {x[1]} and Number of people having sex as 0 are {x[0]}')
p = sns.countplot(data=df, x='sex')
plt.show()
# Out:
# Number of people having sex as 1 are 206 and Number of people having sex as 0 are 96

# %%
x = (df.cp.value_counts())
print(x)
p = sns.countplot(data=df, x='cp')
plt.show()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %% [markdown]
# Age distribution

# %%
plt.figure(figsize=(10,10))
sns.displot(df.age , color='red', label='age', kde=True)
plt.legend()

# %%
plt.figure(figsize=(10,10))
sns.displot(df.trtbps , color='green', label='resting blood pressure', kde=True)
plt.legend()

# %%
plt.figure(figsize=(10,10))
sns.histplot(df[df['output']==0]['age'], color='green', kde=True)
sns.histplot(df[df['output']==1]['age'], color='red', kde=True)
plt.title('Attack vs Age')
plt.legend()
plt.show()
# Out:
# C:\Users\pulki\AppData\Local\Temp\ipykernel_23612\1268307725.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(10,10))
sns.histplot(df[df['output']==0]['chol'], color='green', kde=True)
sns.histplot(df[df['output']==1]['chol'], color='red', kde=True)
plt.title('Attack vs Age')
plt.legend()
plt.show()
# Out:
# C:\Users\pulki\AppData\Local\Temp\ipykernel_23612\1731919874.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
y=df.iloc[:,-1].values
x=df.iloc[:,1:-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(x, y, random_state=42, test_size=0.25)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = 
from sklearn.metrics import accuracy_score
accuracy_score(y_pred, y_test)
